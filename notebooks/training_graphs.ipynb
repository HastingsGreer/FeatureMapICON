# %%
import torch
import matplotlib.pyplot as plt
paths = [
    "../../bak_FeatureMapICON/pytorch/results/no_crop_no_pretrain/loss00019.trch",
    "../results/kinetics_train/loss00006.trch",
    "../results/hjkl/loss00002.trch",
    "../results/kinetics_adam_scale7/loss00002.trch",
    "../results/kinetics_rmsprop_sc12/loss00008.trch"
]

# %%
losses = [torch.load(path) for path in paths]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23773/3141932402.py in <module>
# ----> 1 losses = [torch.load(path) for path in paths]
#
# /tmp/ipykernel_23773/3141932402.py in <listcomp>(.0)
# ----> 1 losses = [torch.load(path) for path in paths]
#
# /playpen1/tgreer/anaconda3/envs/corr_ext/lib/python3.9/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592         pickle_load_args['encoding'] = 'utf-8'
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#     596             # The zipfile reader is going to advance the current file position.
#
# /playpen1/tgreer/anaconda3/envs/corr_ext/lib/python3.9/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /playpen1/tgreer/anaconda3/envs/corr_ext/lib/python3.9/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/kinetics_rmsprop_sc12/loss00008.trch'

# %%
for l in losses:
    plt.plot(l[:2500])
plt.grid()
    
import numpy as np
x = np.arange(15000)

#plt.plot(7 * .9999**x)
plt.ylabel("log P(transform is inverse consistent)")
# Out:
# Text(0, 0.5, 'log P(transform is inverse consistent)')

# %%
np.minimum(np.arange(15000) + 1, 9)
# Out:
# array([1, 2, 3, ..., 9, 9, 9])

# %%
plt.plot(losses[1][:50])
plt.plot(losses[-1][:50])
