# %%
import torch
import matplotlib.pyplot as plt
paths = [
    #"results/overnight_mayhaps_to_dream/loss00008.trch",
    #"results/deeeep_warp/loss00009.trch",
    #"results/rebooted_wwarping/loss00007.trch",
    #"results/warping3/loss00009.trch",
    #"results/slower_warped_rmsprop/loss00040.trch",
    "results/no_crop_no_pretrain/loss00019.trch",
    "results/60x60Iguess/loss00017.trch",
    "results/60x60_drop/loss00008.trch"
]

# %%
losses = [torch.load(path) for path in paths]

# %%
for l in losses:
    plt.plot(l)
plt.grid()
    
import numpy as np
x = np.arange(15000)

#plt.plot(7 * .9999**x)
plt.ylabel("log P(transform is inverse consistent)")
# Out:
# Text(0, 0.5, 'log P(transform is inverse consistent)')

# %%
np.minimum(np.arange(15000) + 1, 9)
# Out:
# array([1, 2, 3, ..., 9, 9, 9])
